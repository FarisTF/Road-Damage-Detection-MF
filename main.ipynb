# %%
from pipeline_func import *

# %%
import os
if not os.path.exists("hehe"):
    os.makedirs("hehe")

# %%
def detection_and_deepsort(pothole_id,output_folder) :
    folder_path = "result/"+output_folder
    path_ss = folder_path + "/ss" + "/" + str(pothole_id) + ".png"
    print(path_ss)

detection_and_deepsort(2, "saskeh")
# Out:
# result/saskeh/ss/2.png

# %% [markdown]
# # Untuk Ngeslowdown Video (video harus masuk sini sebelum lanjut)

# %%
print("Start") # Biar bisa keliatan progressnya (kalo dijalanin di vscode)

vid_path = slow_down_video("input/1.mp4", "slowed/3_slowed.mp4")
print(vid_path)

# %% [markdown]
# # Untuk Mendeteksi Pothole (input video harus udah dislow down)

# %%
print("Start") # Biar bisa keliatan progressnya (kalo dijalanin di vscode)

input_video = "slowed/1_slowed.mp4"
output_video = "result/hehe.mp4"
output_csv = "result/hehe.csv"

hasil = detection_and_deepsort(input_video,
                       "model/pothole", 
                       0.4, 1.0,
                       output_video,
                       output_csv)
# Out:
# Start
# Frame #:  1
# FPS: 0.25
# Frame #:  2
# FPS: 77.62
# Frame #:  3
# FPS: 88.24
# Frame #:  4
# FPS: 86.28
# Frame #:  5
# FPS: 83.32
# Frame #:  6
# FPS: 77.31
# Frame #:  7
# FPS: 23.77
# Frame #:  8
# FPS: 47.91
# Frame #:  9
# FPS: 51.85
# Frame #:  10
# FPS: 71.40
# Frame #:  11
# FPS: 64.61
# Frame #:  12
# FPS: 92.61
# Frame #:  13
# FPS: 86.33
# Frame #:  14
# FPS: 81.52
# Frame #:  15
# FPS: 74.35
# Frame #:  16
# FPS: 83.87
# Frame #:  17
# FPS: 94.45
# Frame #:  18
# FPS: 88.40
# Frame #:  19
# FPS: 89.68
# Frame #:  20
# FPS: 90.12
# Frame #:  21
# FPS: 100.53
# Frame #:  22
# FPS: 104.49
# Frame #:  23
# FPS: 99.17
# Frame #:  24
# FPS: 66.43
# Frame #:  25
# FPS: 33.11
# Frame #:  26
# FPS: 42.38
# Frame #:  27
# FPS: 39.65
# Frame #:  28
# FPS: 26.91
# Frame #:  29
# FPS: 22.16
# Frame #:  30
# FPS: 28.58
# Frame #:  31
# FPS: 44.92
# Frame #:  32
# FPS: 85.05
# Frame #:  33
# FPS: 2.44
# Frame #:  34
# FPS: 62.37
# Frame #:  35
# hehe
# ...

# %% [markdown]
# # Untuk Mendeteksi Alligator Crack (input video harus udah dislow down)

# %%
print("Start") # Biar bisa keliatan progressnya (kalo dijalanin di vscode)

input_video = "slowed/1_slowed.mp4"
output_video = "result/punya_furkon.mp4"
output_csv = "result/punya_furkon.csv"

hasil = detection_and_deepsort(input_video,
                       "model/alligator_crack", 
                       0.4, 1.0,
                       output_video,
                       output_csv)
